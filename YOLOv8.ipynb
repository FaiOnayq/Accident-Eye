# %%
# !pip install ultralytics
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# # Accident-Eye : YOLOv8m

# %%
from ultralytics import YOLO

model = YOLO("yolov8m-cls.pt")

# Tune hyperparameters on COCO8 for 100 epochs

model.train(data="C:/Users/Admin/Desktop/Gradution project 2/yolop/dataset123n_train_test", epochs=100,batch=32,weight_decay=0.0005, imgsz=320)
# Out:
# New https://pypi.org/project/ultralytics/8.3.58 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.38  Python-3.12.6 torch-2.5.1+cu124 CUDA:0 (NVIDIA GeForce RTX 4060, 8188MiB)
# ...
